# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a206-stack/python/blob/main/university_marks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Student Details ---
name = input("Enter Student Name: ")
roll = input("Enter Roll Number: ")
num_subjects = int(input("Enter Number of Subjects: "))
subjects = []
for i in range(num_subjects):
    print(f"\n--- Subject {i+1} ---")
    subject_name = input("Enter Subject Name: ")
    internal1 = int(input("Internal-1 Marks : "))
    internal2 = int(input("Internal-2 Marks : "))
    assignment = int(input("Assignment Marks : "))
    external = int(input("External Exam Marks : "))
    # Internal marks (out of 40)
    avg_internal = (internal1 + internal2) / 2
    internal_total = avg_internal + assignment
    # External marks (out of 60)
    external_total = (external / 100) * 60
    # Final total (out of 100)
    final_total = internal_total + external_total
    # --- Grade function in the middle ---
    def calculate_grade(total_marks):
        if total_marks >= 90:
            return "O"
        elif total_marks >= 80:
            return "A+"
        elif total_marks >= 70:
            return "A"
        elif total_marks >= 60:
            return "B+"
        elif total_marks >= 50:
            return "B"
        elif total_marks >= 40:
            return "C"
        else:
            return "F"
    grade = calculate_grade(final_total)
    # Pass/Fail check
    if internal_total < 20 or external_total < 30:
        result = "FAIL"
        grade = "F"
    else:
        result = "PASS"
    subjects.append([subject_name, internal_total, external_total, final_total, result, grade])
# --- Print Marksheet ---
print("\n==============================")
print(" MARKSHEET")
print("==============================")
print(f"Name : {name}")
print(f"Roll : {roll}")
print("------------------------------")
print(f"{'Subject':<15}{'Internal(40)':<15}{'External(60)':<15}{'Total(100)':<15}{'Result':<10}{'Grade':<5}")
print("-"*75)
for sub in subjects:
    print(f"{sub[0]:<15}{sub[1]:<15.2f}{sub[2]:<15.2f}{sub[3]:<15.2f}{sub[4]:<10}{sub[5]:<5}")
print("="*75)
# Out:
# Enter Student Name: M.Pramodh
# Enter Roll Number: 11249A206
# Enter Number of Subjects: 4
#
# --- Subject 1 ---
# Enter Subject Name: oops lab
# Internal-1 Marks : 26
# Internal-2 Marks : 26
# Assignment Marks : 10
# External Exam Marks : 93
#
# --- Subject 2 ---
# Enter Subject Name: python
# Internal-1 Marks : 27
# Internal-2 Marks : 28
# Assignment Marks : 10
# External Exam Marks : 94
#
# --- Subject 3 ---
# Enter Subject Name: maths-3
# Internal-1 Marks : 22
# Internal-2 Marks : 25
# Assignment Marks : 9
# External Exam Marks : 90
#
# --- Subject 4 ---
# Enter Subject Name: c lab
# Internal-1 Marks : 24
# Internal-2 Marks : 28
# Assignment Marks : 9
# External Exam Marks : 93
#
# ...
#  MARKSHEET
# ...
# Name : M.Pramodh
# Roll : 11249A206
# ------------------------------
# Subject        Internal(40)   External(60)   Total(100)     Result    Grade
# ---------------------------------------------------------------------------
# ...
